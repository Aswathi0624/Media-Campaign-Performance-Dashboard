# %%
import pandas as pd

# %%
df = pd.read_csv("media_campaign_data.csv")
df
# Out:
#      Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0    NY-CMP-1000  Social Media       College Students        21
# 1    NY-CMP-1001      Paid Ads  Tier 2 City Customers        18
# 2    NY-CMP-1002    Influencer                  Youth        23
# 3    NY-CMP-1003         Email          Working Women        18
# 4    NY-CMP-1004      Paid Ads       College Students        10
# ..           ...           ...                    ...       ...
# 194  NY-CMP-1194    Influencer       Premium Shoppers         7
# 195  NY-CMP-1195    Influencer       College Students         9
# 196  NY-CMP-1196           SEO       College Students        16
# 197  NY-CMP-1197  Social Media       Premium Shoppers        13
# 198  NY-CMP-1198      Paid Ads       Premium Shoppers        12
#
#                      Channel_Used  Impressions  Clicks  Leads  Conversions  \
# 0               WhatsApp, YouTube        57804    6156   3616         2355
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       199 non-null    object
#  1   Campaign_Type     199 non-null    object
#  2   Target_Audience   199 non-null    object
#  3   Duration          199 non-null    int64
#  4   Channel_Used      199 non-null    object
#  5   Impressions       199 non-null    int64
#  6   Clicks            199 non-null    int64
#  7   Leads             199 non-null    int64
#  8   Conversions       199 non-null    int64
#  9   Revenue           199 non-null    int64
#  10  Acquisition_Cost  199 non-null    float64
#  11  ROI               199 non-null    float64
#  12  Customer_Segment  199 non-null    object
#  13  Date              199 non-null    object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 21.9+ KB

# %%
df.dtypes
# Out:
# Campaign_ID          object
# Campaign_Type        object
# Target_Audience      object
# Duration              int64
# Channel_Used         object
# Impressions           int64
# Clicks                int64
# Leads                 int64
# Conversions           int64
# Revenue               int64
# Acquisition_Cost    float64
# ROI                 float64
# Customer_Segment     object
# Date                 object
# dtype: object

# %%
df.isna().sum()
# Out:
# Campaign_ID         0
# Campaign_Type       0
# Target_Audience     0
# Duration            0
# Channel_Used        0
# Impressions         0
# Clicks              0
# Leads               0
# Conversions         0
# Revenue             0
# Acquisition_Cost    0
# ROI                 0
# Customer_Segment    0
# Date                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Date"] = pd.to_datetime(
    df["Date"],
    format="mixed",
    dayfirst=True,
    errors="coerce"
)

# %%
df["Date"] = (
    df["Date"]
    .astype(str)
    .str.strip()
)

df["Date"] = pd.to_datetime(
    df["Date"],
    errors="coerce"
)

# %%
df['Date']
# Out:
# 0     2025-04-29
# 1     2025-04-06
# 2     2025-01-14
# 3     2025-06-04
# 4     2024-12-29
#          ...
# 194   2025-05-27
# 195   2025-02-22
# 196   2025-05-30
# 197   2024-08-29
# 198   2025-03-16
# Name: Date, Length: 199, dtype: datetime64[ns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       199 non-null    object
#  1   Campaign_Type     199 non-null    object
#  2   Target_Audience   199 non-null    object
#  3   Duration          199 non-null    int64
#  4   Channel_Used      199 non-null    object
#  5   Impressions       199 non-null    int64
#  6   Clicks            199 non-null    int64
#  7   Leads             199 non-null    int64
#  8   Conversions       199 non-null    int64
#  9   Revenue           199 non-null    int64
#  10  Acquisition_Cost  199 non-null    float64
#  11  ROI               199 non-null    float64
#  12  Customer_Segment  199 non-null    object
#  13  Date              199 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(6), object(5)
# memory usage: 21.9+ KB
# None

# %%
df = df.fillna(0)

# %%
df = df.drop_duplicates()

# %%
print(df.shape)
# Out:
# (199, 14)

# %%
pd.to_datetime(df["Date"], format="%d-%m-%Y")
# Out:
# 0     2025-04-29
# 1     2025-04-06
# 2     2025-01-14
# 3     2025-06-04
# 4     2024-12-29
#          ...
# 194   2025-05-27
# 195   2025-02-22
# 196   2025-05-30
# 197   2024-08-29
# 198   2025-03-16
# Name: Date, Length: 199, dtype: datetime64[ns]

# %%
df
df.to_csv("cleaned_media_data.csv", index=False)

# %%
df
# Out:
#      Campaign_ID Campaign_Type        Target_Audience  Duration  \
# 0    NY-CMP-1000  Social Media       College Students        21
# 1    NY-CMP-1001      Paid Ads  Tier 2 City Customers        18
# 2    NY-CMP-1002    Influencer                  Youth        23
# 3    NY-CMP-1003         Email          Working Women        18
# 4    NY-CMP-1004      Paid Ads       College Students        10
# ..           ...           ...                    ...       ...
# 194  NY-CMP-1194    Influencer       Premium Shoppers         7
# 195  NY-CMP-1195    Influencer       College Students         9
# 196  NY-CMP-1196           SEO       College Students        16
# 197  NY-CMP-1197  Social Media       Premium Shoppers        13
# 198  NY-CMP-1198      Paid Ads       Premium Shoppers        12
#
#                      Channel_Used  Impressions  Clicks  Leads  Conversions  \
# 0               WhatsApp, YouTube        57804    6156   3616         2355
# ...
